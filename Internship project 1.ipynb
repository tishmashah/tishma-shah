# %%
import pandas as pd
df= pd.read_csv('student_exam_scores.csv')
df.head(10)
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  \
# 0       S001            8.0          8.8                72.1               45
# 1       S002            1.3          8.6                60.7               55
# 2       S003            4.0          8.2                73.7               86
# 3       S004            3.5          4.8                95.1               66
# 4       S005            9.1          6.4                89.8               71
# 5       S006            8.4          5.1                58.5               75
# 6       S007           10.8          6.0                54.2               88
# 7       S008            2.0          4.3                75.8               55
# 8       S009            5.6          5.9                81.6               84
# 9       S010            1.3          8.9                66.8               70
#
#    exam_score
# 0        30.2
# 1        25.0
# 2        35.8
# 3        34.0
# 4        40.3
# 5        35.7
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# ...

# %%
data.tail()
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 195               87        42.7
# 196               92        40.4
# 197               76        28.2
# 198               58        42.0
# 199               68        37.8

# %%
import pandas as pd
df = pd.read_csv('student_exam_scores.csv')
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
import pandas as pd
df = pd.read_csv('student_exam_scores.csv')
print(df.isnull().sum())
# Out:
# student_id            0
# hours_studied         0
# sleep_hours           0
# attendance_percent    0
# previous_scores       0
# exam_score            0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('student_exam_scores.csv')
print(df.describe())
# Out:
#        hours_studied  sleep_hours  attendance_percent  previous_scores  \
# count     200.000000   200.000000          200.000000       200.000000
# mean        6.325500     6.622000           74.830000        66.800000
# std         3.227317     1.497138           14.249905        15.663869
# min         1.000000     4.000000           50.300000        40.000000
# 25%         3.500000     5.300000           62.200000        54.000000
# 50%         6.150000     6.700000           75.250000        67.500000
# 75%         9.000000     8.025000           87.425000        80.000000
# max        12.000000     9.000000          100.000000        95.000000
#
#        exam_score
# count  200.000000
# mean    33.955000
# std      6.789548
# min     17.100000
# 25%     29.500000
# 50%     34.050000
# 75%     38.750000
# max     51.300000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6,5))
sns.barplot(x="exam_score",y="sleep_hours",data=df)
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.plot(df['sleep_hours'],df['exam_score'],marker='s')
plt.xlabel('sleep_hours')
plt.ylabel('exam_score')
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.scatterplot(x='student_id',y='previous_scores',data=df)
plt.title('student_id vs previous_scores')
plt.show()

# %%
plt.figure(figsize=(8,7))
plt.hist(df['student_id'],bins=10,color='red',edgecolor='black')
plt.title('sleep_hours')
plt.xlabel('student_id')
plt.ylabel('exam_score')
plt.show()

# %%
corr=df.corr(numeric_only=True)
plt.figure(figsize=(8,5))
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.title('correlation heatmap')
plt.show()

# %%
import pandas as pd
print(df.shape)
# Out:
# (200, 6)

# %%
print(df['sleep_hours'].mean())
print(df['sleep_hours'].max())
print(df['sleep_hours'].min())
# Out:
# 6.621999999999999
# 9.0
# 4.0

# %%
grouped=df.groupby('hours_studied')['student_id'].sum()
print(grouped)
# Out:
# hours_studied
# 1.0             S125
# 1.1         S020S101
# 1.2             S127
# 1.3     S002S010S013
# 1.4             S068
#             ...
# 11.5        S025S110
# 11.7        S034S099
# 11.8            S183
# 11.9        S061S151
# 12.0    S087S097S199
# Name: student_id, Length: 96, dtype: object

# %%
filtered=df[df['attendance_percent']>500]
print(filtered)
# Out:
# Empty DataFrame
# Columns: [student_id, hours_studied, sleep_hours, attendance_percent, previous_scores, exam_score]
# Index: []

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.metrics import classification_report
from sklearn.linear_model import Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
data=pd.read_csv('student_exam_scores.csv')
print(data.head())
x=data[['sleep_hours','exam_score','attendance_percent']]
y=data['hours_studied']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
Scaler_X = StandardScaler()
Scaler_y = StandardScaler()
X_test_Scaled = Scaler_X.fit_transform(x_train)
X_test_Scaled = Scaler_X.transform(x_test)
y_train_Scaled = Scaler_y.fit_transform(y_train.values.reshape(-1,1)).flatten()
model= LinearRegression()
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  \
# 0       S001            8.0          8.8                72.1               45
# 1       S002            1.3          8.6                60.7               55
# 2       S003            4.0          8.2                73.7               86
# 3       S004            3.5          4.8                95.1               66
# 4       S005            9.1          6.4                89.8               71
#
#    exam_score
# 0        30.2
# 1        25.0
# 2        35.8
# 3        34.0
# 4        40.3

# %%
models = {
    'LinearRgression': LinearRegression(),
    'Ridge': Ridge(),
    'Lasso': Lasso(),
    'Decision Tree': DecisionTreeRegressor(random_state=42,max_depth=10),
    'Random Forest': RandomForestRegressor(n_estimators=100, random_state=42, max_depth=10)
}
import numpy as np 
import pandas as pd

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
Scaler_X = StandardScaler()
Scaler_y = StandardScaler()
X_train_Scaled = Scaler_X.fit_transform(x_train)
X_test_Scaled = Scaler_X.transform(x_test)
y_train_Scaled = Scaler_y.fit_transform(y_train.values.reshape(-1,1)).flatten()
model= LinearRegression()
result = {}
for name, model in models.items():
    model.fit(X_train_Scaled,y_train_Scaled)
    y_pred_scaled = model.predict(X_test_Scaled)
    y_pred = Scaler_y.inverse_transform(y_pred_scaled.reshape(-1,1)).flatten()
    result[name] = {
        "R2" : r2_score(y_test, y_pred),
        "RMSE" : np.sqrt(mean_squared_error(y_test, y_pred))
    }
results_df = pd.DataFrame(result).T
results_df
# Out:
#                        R2      RMSE
# LinearRgression  0.696533  1.882529
# Ridge            0.695942  1.884361
# Lasso           -0.017533  3.447151
# Decision Tree    0.327164  2.803114
# Random Forest    0.618660  2.110290

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['hours_studied'], bins=30, kde=True, color='blue')
plt.title('Distribution of exam_score')
plt.xlabel('hours_studied')
plt.ylabel('exam_score')
plt.show()

# %%
# !pip install streamlit

# %%
# !Streamlit hello
